# %% [markdown]
# # Cleaning MagnaProbe Data
# ## This notebook demonstrates how the pandas and geopandas Python libraries clean up 'raw' magnaprobe data.
# ### Notice how the DataFrame changes in each cell. New columns are appended to the end.

# %%
import magnaprobe
help(magnaprobe)
# Out:
# Help on module magnaprobe:
#
# NAME
#     magnaprobe - # A Module to Clean MagnaProbe Data
#
# FUNCTIONS
#     consolidate_coords(df)
#         Consolidate coordinate information that is split across many columns
#
#     convert_depth_cm_to_m(df)
#         Convert snow depth in cm to snow depth in m. cm column is retained.
#
#     convert_wgs_to_utm(gdf, epsg_code)
#         Convert WGS 84 GeoDataFrame to UTM GeoDataFrame
#
#     create_geodataframe(df)
#         Create GeoDataFrame with WGS 84 Spatial Reference
#
#     create_geometry(df)
#         Add Geometry column to specify lat and lon are special, i.e. point vector data
#
#     drop_calibration_points(df, calibration_prefix, c1, c2)
#         Drop calibration points.
#
#         Calibration points are typically sequences of repeating or alternating ~0 cm and
#         ~120 cm depth measurements. Ideally these are keyed with a different counter
#         number when collected in the field, e.g. they all start with 99.
#         But we can also check for the 0-120 sequences in case the operator failed to change
#         the counter. There are many sequences(e.g. 0-0-120, 120-0-0, etc. so the patterns
#         are ugly but they work!
#
#     read_tabular(raw_file, header_row)
#         Read 'raw' MagnaProbe data (*. xls, *.dat, *.csv, etc.) to DataFrame
#
#     save_as_csv(df, out_dst)
#         Save a Clean CSV File
#
#     save_as_shp(gdf, out_dst)
#         Save a point shapefile ready for GIS
#
#     strip_junk_rows(raw_df, first_n_rows)
#         Drop n header rows that are not needed
#
#     trim_cols(df, list_of_cols_to_keep)
#         Remove all columns except list of columns specified by user to retain.
#
# FILE
#     /home/cparr/workspace/magnaprobe_tools/magnaprobe-tools/magnaprobe.py

# %%
raw = magnaprobe.read_tabular('example_data/Geo2_4_raw.dat', 1)
raw.head()
# Out:
#                 TIMESTAMP RECORD Counter DepthCm BattVolts latitude_a  \
# 0                      TS     RN     NaN     NaN       NaN    degrees
# 1                     NaN    NaN     Smp     Smp       Smp        Smp
# 2  2017-11-14 11:27:00.75   5721  100001   7.283     13.75         65
# 3  2017-11-14 15:14:14.75   5722  100002   7.732     13.78         65
# 4     2017-11-14 15:14:15   5723  100003   4.138     13.75         65
#
#   latitude_b Longitude_a Longitude_b fix_quality  ... altitudeB DepthVolts  \
# 0    minutes     degrees     minutes    unitless  ...       NaN        NaN
# 1        Smp         Smp         Smp         Smp  ...       Smp        Smp
# 2     2.4724        -147    -25.0191           1  ...     723.9       0.48
# 3     2.4724        -147    -25.0163           1  ...     723.1       0.51
# 4     2.4721        -147    -25.0147           1  ...     729.4       0.28
#
#   LatitudeDDDDD LongitudeDDDDD month dayofmonth hourofday minutes seconds  \
# 0           NaN            NaN   NaN        NaN       NaN     NaN     NaN
# 1           Smp            Smp   Smp        Smp       Smp     Smp     Smp
# 2    0.04120666      -0.416985    11         14        11      27       0
# 3    0.04120666     -0.4169383    11         14        15      14      14
# 4    0.04120166     -0.4169117    11         14        15      14      15
#
#   microseconds
# 0          NaN
# 1          Smp
# 2       750000
# 3       750000
# 4            0
#
# [5 rows x 22 columns]

# %%
magnaprobe.strip_junk_rows(raw, 2)
raw.head()
# Out:
#                 TIMESTAMP RECORD Counter DepthCm BattVolts latitude_a  \
# 2  2017-11-14 11:27:00.75   5721  100001   7.283     13.75         65
# 3  2017-11-14 15:14:14.75   5722  100002   7.732     13.78         65
# 4     2017-11-14 15:14:15   5723  100003   4.138     13.75         65
# 5  2017-11-14 15:14:15.25   5724  999001   -0.19     13.75         65
# 6  2017-11-14 15:14:15.75   5725  999002   -0.13     13.74         65
#
#   latitude_b Longitude_a Longitude_b fix_quality  ... altitudeB DepthVolts  \
# 2     2.4724        -147    -25.0191           1  ...     723.9       0.48
# 3     2.4724        -147    -25.0163           1  ...     723.1       0.51
# 4     2.4721        -147    -25.0147           1  ...     729.4       0.28
# 5     2.4704        -147    -25.0147           1  ...       729      -0.00
# 6     2.4704        -147    -25.0147           2  ...     728.9          0
#
#   LatitudeDDDDD LongitudeDDDDD month dayofmonth hourofday minutes seconds  \
# 2    0.04120666      -0.416985    11         14        11      27       0
# 3    0.04120666     -0.4169383    11         14        15      14      14
# 4    0.04120166     -0.4169117    11         14        15      14      15
# 5    0.04117334     -0.4169117    11         14        15      14      15
# 6    0.04117334     -0.4169117    11         14        15      14      15
#
#   microseconds
# 2       750000
# 3       750000
# 4            0
# 5       250000
# 6       750000
#
# [5 rows x 22 columns]

# %%
df = magnaprobe.consolidate_coords(raw)
df.head()
# Out:
#                 timestamp record counter depthcm battvolts latitude_a  \
# 2  2017-11-14 11:27:00.75   5721  100001   7.283     13.75         65
# 3  2017-11-14 15:14:14.75   5722  100002   7.732     13.78         65
# 4     2017-11-14 15:14:15   5723  100003   4.138     13.75         65
# 5  2017-11-14 15:14:15.25   5724  999001   -0.19     13.75         65
# 6  2017-11-14 15:14:15.75   5725  999002   -0.13     13.74         65
#
#   latitude_b longitude_a longitude_b fix_quality  ... latitudeddddd  \
# 2     2.4724        -147    -25.0191           1  ...    0.04120666
# 3     2.4724        -147    -25.0163           1  ...    0.04120666
# 4     2.4721        -147    -25.0147           1  ...    0.04120166
# 5     2.4704        -147    -25.0147           1  ...    0.04117334
# 6     2.4704        -147    -25.0147           2  ...    0.04117334
#
#   longitudeddddd month dayofmonth hourofday minutes seconds microseconds  \
# 2      -0.416985    11         14        11      27       0       750000
# 3     -0.4169383    11         14        15      14      14       750000
# 4     -0.4169117    11         14        15      14      15            0
# 5     -0.4169117    11         14        15      14      15       250000
# 6     -0.4169117    11         14        15      14      15       750000
#
#     Latitude   Longitude
# 2  65.041207 -147.416985
# 3  65.041207 -147.416938
# 4  65.041202 -147.416912
# 5  65.041173 -147.416912
# 6  65.041173 -147.416912
#
# [5 rows x 24 columns]

# %%
depth_df = magnaprobe.convert_depth_cm_to_m(df)
depth_df.head()
# Out:
#                 timestamp record counter depthcm battvolts latitude_a  \
# 2  2017-11-14 11:27:00.75   5721  100001   7.283     13.75         65
# 3  2017-11-14 15:14:14.75   5722  100002   7.732     13.78         65
# 4     2017-11-14 15:14:15   5723  100003   4.138     13.75         65
# 5  2017-11-14 15:14:15.25   5724  999001   -0.19     13.75         65
# 6  2017-11-14 15:14:15.75   5725  999002   -0.13     13.74         65
#
#   latitude_b longitude_a longitude_b fix_quality  ... longitudeddddd month  \
# 2     2.4724        -147    -25.0191           1  ...      -0.416985    11
# 3     2.4724        -147    -25.0163           1  ...     -0.4169383    11
# 4     2.4721        -147    -25.0147           1  ...     -0.4169117    11
# 5     2.4704        -147    -25.0147           1  ...     -0.4169117    11
# 6     2.4704        -147    -25.0147           2  ...     -0.4169117    11
#
#   dayofmonth hourofday minutes seconds microseconds   Latitude   Longitude  \
# 2         14        11      27       0       750000  65.041207 -147.416985
# 3         14        15      14      14       750000  65.041207 -147.416938
# 4         14        15      14      15            0  65.041202 -147.416912
# 5         14        15      14      15       250000  65.041173 -147.416912
# 6         14        15      14      15       750000  65.041173 -147.416912
#
#   Snow Depth m
# 2      0.07283
# 3      0.07732
# 4      0.04138
# 5     -0.00190
# 6     -0.00130
#
# [5 rows x 25 columns]

# %%
# Select which columns to keep. Maybe you want to know the voltage.
# Or maybe your MagnaProbe internals are programmed with different column names.
clean_df = magnaprobe.trim_cols(depth_df, ['timestamp', 'counter',
                                           'Latitude', 'Longitude',
                                           'Snow Depth m'])
clean_df.head()
# Out:
#                 timestamp counter   Latitude   Longitude  Snow Depth m
# 2  2017-11-14 11:27:00.75  100001  65.041207 -147.416985       0.07283
# 3  2017-11-14 15:14:14.75  100002  65.041207 -147.416938       0.07732
# 4     2017-11-14 15:14:15  100003  65.041202 -147.416912       0.04138
# 5  2017-11-14 15:14:15.25  999001  65.041173 -147.416912      -0.00190
# 6  2017-11-14 15:14:15.75  999002  65.041173 -147.416912      -0.00130

# %%
clean_df = magnaprobe.drop_calibration_points(clean_df, 99, 0.02, 1.18)
# Out:
# Starting number of rows: 251
# Rows left after culling by counter prefix: 241
# Rows left after culling by calibration patterns: 237

# %%
geom_df = magnaprobe.create_geometry(clean_df)
geom_df.head()
# Out:
#                  timestamp counter   Latitude   Longitude  Snow Depth m  \
# 2   2017-11-14 11:27:00.75  100001  65.041207 -147.416985       0.07283
# 3   2017-11-14 15:14:14.75  100002  65.041207 -147.416938       0.07732
# 4      2017-11-14 15:14:15  100003  65.041202 -147.416912       0.04138
# 15  2017-11-14 15:24:38.25  100001  65.040580 -147.417213      -0.00130
# 16   2017-11-14 15:24:38.5  100002  65.040293 -147.417950       0.78920
#
#                                   geometry
# 2          POINT (-147.416985 65.04120666)
# 3         POINT (-147.4169383 65.04120666)
# 4         POINT (-147.4169117 65.04120166)
# 15  POINT (-147.4172134 65.04058000000001)
# 16          POINT (-147.41795 65.04029333)

# %%
geo_df = magnaprobe.create_geodataframe(geom_df)
geo_df.head()
# Out:
#                  timestamp counter   Latitude   Longitude  Snow Depth m  \
# 2   2017-11-14 11:27:00.75  100001  65.041207 -147.416985       0.07283
# 3   2017-11-14 15:14:14.75  100002  65.041207 -147.416938       0.07732
# 4      2017-11-14 15:14:15  100003  65.041202 -147.416912       0.04138
# 15  2017-11-14 15:24:38.25  100001  65.040580 -147.417213      -0.00130
# 16   2017-11-14 15:24:38.5  100002  65.040293 -147.417950       0.78920
#
#                        geometry
# 2   POINT (-147.41699 65.04121)
# 3   POINT (-147.41694 65.04121)
# 4   POINT (-147.41691 65.04120)
# 15  POINT (-147.41721 65.04058)
# 16  POINT (-147.41795 65.04029)

# %%
# 32606 is the EPSG code for UTM Zone 6 N
utm_geo_df = magnaprobe.convert_wgs_to_utm(geo_df, 32606)
utm_geo_df.head()
# Out:
#                  timestamp counter   Latitude   Longitude  Snow Depth m  \
# 2   2017-11-14 11:27:00.75  100001  65.041207 -147.416985       0.07283
# 3   2017-11-14 15:14:14.75  100002  65.041207 -147.416938       0.07732
# 4      2017-11-14 15:14:15  100003  65.041202 -147.416912       0.04138
# 15  2017-11-14 15:24:38.25  100001  65.040580 -147.417213      -0.00130
# 16   2017-11-14 15:24:38.5  100002  65.040293 -147.417950       0.78920
#
#                           geometry
# 2   POINT (480366.787 7213111.766)
# 3   POINT (480368.986 7213111.752)
# 4   POINT (480370.235 7213111.186)
# 15  POINT (480355.573 7213041.998)
# 16  POINT (480320.679 7213010.279)
